# %% [markdown]
# # MLRun
# # Nuclio - Training function
# ## Environment
# Preperation for MLRun (Until pip-install version)

# %%
# nuclio: ignore
# !pip install nest_asyncio
# !pip install aiohttp
# !pip install git+https://github.com/nuclio/nuclio-jupyter.git@enhance-spec
# !pip install git+https://github.com/v3io/mlrun.git
# Out:
# Requirement already satisfied: nest_asyncio in /User/.pythonlibs/lib/python3.6/site-packages (1.0.0)
# Requirement already satisfied: aiohttp in /User/.pythonlibs/lib/python3.6/site-packages (3.5.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp) (1.3.0)
# Requirement already satisfied: multidict<5.0,>=4.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp) (4.5.2)
# Requirement already satisfied: attrs>=17.3.0 in /conda/lib/python3.6/site-packages (from aiohttp) (19.1.0)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp) (3.7.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in /conda/lib/python3.6/site-packages (from aiohttp) (3.0.4)
# Requirement already satisfied: idna>=2.0 in /conda/lib/python3.6/site-packages (from yarl<2.0,>=1.0->aiohttp) (2.8)
# Collecting git+https://github.com/nuclio/nuclio-jupyter.git@enhance-spec
#   Cloning https://github.com/nuclio/nuclio-jupyter.git (to revision enhance-spec) to /tmp/pip-req-build-3uf_0yf7
# Branch 'enhance-spec' set up to track remote branch 'enhance-spec' from 'origin'.
# Switched to a new branch 'enhance-spec'
# Requirement already satisfied (use --upgrade to upgrade): nuclio-jupyter==0.7.4 from git+https://github.com/nuclio/nuclio-jupyter.git@enhance-spec in /User/.pythonlibs/lib/python3.6/site-packages
# Requirement already satisfied: ipython>=7.2 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (7.6.1)
# Requirement already satisfied: jupyterlab>=0.35.4 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (1.0.2)
# Requirement already satisfied: nbconvert>=5.4 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (5.5.0)
# Requirement already satisfied: notebook>=5.7.2 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (6.0.0)
# Requirement already satisfied: nuclio-sdk>=0.0.3 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (0.0.5)
# Requirement already satisfied: pyyaml>=3.13 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (5.1.1)
# Requirement already satisfied: requests>=2.20.1 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (2.22.0)
# Requirement already satisfied: tornado<6,>=5 in /User/.pythonlibs/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (5.1.1)
# Requirement already satisfied: boto3>=1.9 in /conda/lib/python3.6/site-packages (from nuclio-jupyter==0.7.4) (1.9.197)
# Requirement already satisfied: pygments in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (2.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (2.0.9)
# Requirement already satisfied: backcall in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (41.0.1)
# Requirement already satisfied: decorator in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (4.4.0)
# Requirement already satisfied: pickleshare in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (4.3.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (4.7.0)
# Requirement already satisfied: jedi>=0.10 in /conda/lib/python3.6/site-packages (from ipython>=7.2->nuclio-jupyter==0.7.4) (0.13.3)
# Requirement already satisfied: jupyterlab_server~=1.0.0rc0 in /conda/lib/python3.6/site-packages (from jupyterlab>=0.35.4->nuclio-jupyter==0.7.4) (1.0.0)
# Requirement already satisfied: testpath in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (0.4.2)
# Requirement already satisfied: jinja2>=2.4 in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (2.10.1)
# Requirement already satisfied: jupyter-core in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (4.5.0)
# Requirement already satisfied: nbformat>=4.4 in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (4.4.0)
# Requirement already satisfied: mistune>=0.8.1 in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (0.8.4)
# Requirement already satisfied: bleach in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (1.4.2)
# Requirement already satisfied: defusedxml in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /conda/lib/python3.6/site-packages (from nbconvert>=5.4->nuclio-jupyter==0.7.4) (0.3)
# Requirement already satisfied: prometheus-client in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (18.0.0)
# Requirement already satisfied: jupyter-client>=5.3.1 in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (0.8.2)
# Requirement already satisfied: ipython-genutils in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (0.2.0)
# Requirement already satisfied: Send2Trash in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (1.5.0)
# Requirement already satisfied: ipykernel in /conda/lib/python3.6/site-packages (from notebook>=5.7.2->nuclio-jupyter==0.7.4) (5.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->nuclio-jupyter==0.7.4) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->nuclio-jupyter==0.7.4) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->nuclio-jupyter==0.7.4) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->nuclio-jupyter==0.7.4) (1.24.2)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /conda/lib/python3.6/site-packages (from boto3>=1.9->nuclio-jupyter==0.7.4) (0.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.197 in /conda/lib/python3.6/site-packages (from boto3>=1.9->nuclio-jupyter==0.7.4) (1.12.197)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /conda/lib/python3.6/site-packages (from boto3>=1.9->nuclio-jupyter==0.7.4) (0.9.4)
# Requirement already satisfied: wcwidth in /conda/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=7.2->nuclio-jupyter==0.7.4) (0.1.7)
# Requirement already satisfied: six>=1.9.0 in /conda/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=7.2->nuclio-jupyter==0.7.4) (1.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /conda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=7.2->nuclio-jupyter==0.7.4) (0.6.0)
# Requirement already satisfied: parso>=0.3.0 in /conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=7.2->nuclio-jupyter==0.7.4) (0.5.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /conda/lib/python3.6/site-packages (from jupyterlab_server~=1.0.0rc0->jupyterlab>=0.35.4->nuclio-jupyter==0.7.4) (3.0.1)
# Requirement already satisfied: json5 in /conda/lib/python3.6/site-packages (from jupyterlab_server~=1.0.0rc0->jupyterlab>=0.35.4->nuclio-jupyter==0.7.4) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /conda/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert>=5.4->nuclio-jupyter==0.7.4) (1.1.1)
# Requirement already satisfied: webencodings in /conda/lib/python3.6/site-packages (from bleach->nbconvert>=5.4->nuclio-jupyter==0.7.4) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in /conda/lib/python3.6/site-packages (from jupyter-client>=5.3.1->notebook>=5.7.2->nuclio-jupyter==0.7.4) (2.8.0)
# Requirement already satisfied: docutils<0.15,>=0.10 in /conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.197->boto3>=1.9->nuclio-jupyter==0.7.4) (0.14)
# Requirement already satisfied: attrs>=17.4.0 in /conda/lib/python3.6/site-packages (from jsonschema>=3.0.1->jupyterlab_server~=1.0.0rc0->jupyterlab>=0.35.4->nuclio-jupyter==0.7.4) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /conda/lib/python3.6/site-packages (from jsonschema>=3.0.1->jupyterlab_server~=1.0.0rc0->jupyterlab>=0.35.4->nuclio-jupyter==0.7.4) (0.14.11)
# Building wheels for collected packages: nuclio-jupyter
#   Running setup.py bdist_wheel for nuclio-jupyter ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aeapvxjk/wheels/27/dd/f2/d906ffa5224575ab70b4c6a404d0d2acda1808960485a5624e
# Successfully built nuclio-jupyter
# Collecting git+https://github.com/v3io/mlrun.git
#   Cloning https://github.com/v3io/mlrun.git to /tmp/pip-req-build-v1bdxxsf
# Requirement already satisfied: requests>=2.20.1 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (2.22.0)
# Requirement already satisfied: boto3>=1.9 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (1.9.197)
# Requirement already satisfied: pyyaml>=5.1.0 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (5.1.1)
# Requirement already satisfied: click>=7.0 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (7.0)
# Requirement already satisfied: pandas>=0.23.0 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (0.23.4)
# Collecting kubernetes>=9.0.0 (from mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/2a/09/365f4ad63f71c698c76edb3e666852b87a751ee4b6d23222b09952557d17/kubernetes-10.0.0-py2.py3-none-any.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 17.5MB/s ta 0:00:01█████████████████▍  | 1.4MB 51.0MB/s eta 0:00:01
# Requirement already satisfied: aiohttp>=3.5.0 in /User/.pythonlibs/lib/python3.6/site-packages (from mlrun==0.1.2) (3.5.4)
# Requirement already satisfied: nest-asyncio>=1.0.0 in /User/.pythonlibs/lib/python3.6/site-packages (from mlrun==0.1.2) (1.0.0)
# Collecting GitPython>=2.1.0 (from mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/3c/d3/aecfe42163233de6071248ea7565e97ba1c51e345a9e1dcc128dd1e46c1e/GitPython-2.1.13-py2.py3-none-any.whl (452kB)
#     100% |████████████████████████████████| 460kB 24.2MB/s ta 0:00:01.9MB/s eta 0:00:01
# Requirement already satisfied: nuclio-sdk>=0.0.3 in /conda/lib/python3.6/site-packages (from mlrun==0.1.2) (0.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->mlrun==0.1.2) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->mlrun==0.1.2) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->mlrun==0.1.2) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /conda/lib/python3.6/site-packages (from requests>=2.20.1->mlrun==0.1.2) (1.24.2)
# Requirement already satisfied: botocore<1.13.0,>=1.12.197 in /conda/lib/python3.6/site-packages (from boto3>=1.9->mlrun==0.1.2) (1.12.197)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /conda/lib/python3.6/site-packages (from boto3>=1.9->mlrun==0.1.2) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /conda/lib/python3.6/site-packages (from boto3>=1.9->mlrun==0.1.2) (0.9.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /conda/lib/python3.6/site-packages (from pandas>=0.23.0->mlrun==0.1.2) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /conda/lib/python3.6/site-packages (from pandas>=0.23.0->mlrun==0.1.2) (2019.1)
# Requirement already satisfied: numpy>=1.9.0 in /conda/lib/python3.6/site-packages (from pandas>=0.23.0->mlrun==0.1.2) (1.16.4)
# Collecting google-auth>=1.0.1 (from kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/c5/9b/ed0516cc1f7609fb0217e3057ff4f0f9f3e3ce79a369c6af4a6c5ca25664/google_auth-1.6.3-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 29.6MB/s ta 0:00:01
# Requirement already satisfied: six>=1.9.0 in /conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->mlrun==0.1.2) (1.12.0)
# Requirement already satisfied: setuptools>=21.0.0 in /conda/lib/python3.6/site-packages (from kubernetes>=9.0.0->mlrun==0.1.2) (41.0.1)
# Collecting requests-oauthlib (from kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl (200kB)
#     100% |████████████████████████████████| 204kB 36.8MB/s ta 0:00:01��████████▍  | 184kB 60.5MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (3.7.4)
# Requirement already satisfied: attrs>=17.3.0 in /conda/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (19.1.0)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (1.1.0)
# Requirement already satisfied: multidict<5.0,>=4.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (4.5.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /User/.pythonlibs/lib/python3.6/site-packages (from aiohttp>=3.5.0->mlrun==0.1.2) (1.3.0)
# Collecting gitdb2>=2.0.0 (from GitPython>=2.1.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/da/30/a407568aa8d8f25db817cf50121a958722f3fc5f87e3a6fba1f40c0633e3/gitdb2-2.0.5-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 34.6MB/s ta 0:00:01
# Requirement already satisfied: docutils<0.15,>=0.10 in /conda/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.197->boto3>=1.9->mlrun==0.1.2) (0.14)
# Collecting cachetools>=2.0.0 (from google-auth>=1.0.1->kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/2f/a6/30b0a0bef12283e83e58c1d6e7b5aabc7acfc4110df81a4471655d33e704/cachetools-3.1.1-py2.py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/91/f0/b03e00ce9fddf4827c42df1c3ce10c74eadebfb706231e8d6d1c356a4062/pyasn1_modules-0.2.5-py2.py3-none-any.whl (74kB)
#     100% |████████████████████████████████| 81kB 29.2MB/s ta 0:00:01
# Collecting rsa>=3.1.4 (from google-auth>=1.0.1->kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/58/5e/289e98ff5ad1a321945803000c5f10f5f90eba346d13139ecdd075cfbe17/oauthlib-3.0.2-py2.py3-none-any.whl (143kB)
#     100% |████████████████████████████████| 153kB 41.1MB/s ta 0:00:01
# Collecting smmap2>=2.0.0 (from gitdb2>=2.0.0->GitPython>=2.1.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/55/d2/866d45e3a121ee15a1dc013824d58072fd5c7799c9c34d01378eb262ca8f/smmap2-2.0.5-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.1 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=9.0.0->mlrun==0.1.2)
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 31.0MB/s ta 0:00:01
# Building wheels for collected packages: mlrun
#   Running setup.py bdist_wheel for mlrun ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nz5z9lng/wheels/2b/0a/b1/2800e59ea6571091083a35a67a92d5d5744a64b61928c849ab
# Successfully built mlrun
# Installing collected packages: cachetools, pyasn1, pyasn1-modules, rsa, google-auth, oauthlib, requests-oauthlib, websocket-client, kubernetes, smmap2, gitdb2, GitPython, mlrun
# Successfully installed GitPython-2.1.13 cachetools-3.1.1 gitdb2-2.0.5 google-auth-1.6.3 kubernetes-10.0.0 mlrun-0.1.2 oauthlib-3.0.2 pyasn1-0.4.5 pyasn1-modules-0.2.5 requests-oauthlib-1.2.0 rsa-4.0 smmap2-2.0.5 websocket-client-0.56.0

# %% [markdown]
# Add MLRun to our python path (Fix until it will be pip-install)

# %% [markdown]
# ### Load nuclio

# %%
# nuclio: ignore
import nuclio

# %% [markdown]
# ## Configurations

# %%
# nuclio: ignore

# Setup environment variables
env_vars = {
    
}

# Function configurations
configs = {
    # Base image
    'spec.build.baseImage': 'python:3.6-jessie',
    
    # Triggers
    'spec.triggers': {
        'web': {
            'kind': 'http', 
            'maxWorkers': 1
        }
    }
}

# Build commands
build_commands = """pip install pyyaml
pip install pyarrow
pip install pandas
pip install v3io_frames --upgrade
pip install scikit-learn==0.20.1
pip install xgboost --upgrade
pip install dask["complete"] --upgrade
pip install dask-ml["complete"] --upgrade
pip install git+https://github.com/v3io/mlrun.git""".splitlines()

# %% [markdown]
# ## Function

# %%
# Utils
import os
import time
import yaml
import pandas as pd
import datetime
import itertools
import pickle

# ML Pipeline Context
from mlrun import get_or_create_ctx, run_start

# DB Connection
import v3io_frames as v3f

# Parallelization
import dask.dataframe as dd
from dask.distributed import Client

# Function
import dask_ml.model_selection as dcv
import xgboost as xgb

# %% [markdown]
# ### Helper functions

# %%
def format_df_from_tsdb(df, shards):
    df.index.names = ['timestamp', 'company', 'data_center', 'device']
    df = df.reset_index()
    df = dd.from_pandas(df, npartitions=shards)
    return df

# %%
def get_data_tsdb(client, features_table, train_on_last, shards):
    df = client.read(backend='tsdb', query=f'select * from {features_table}',
                     start=f'now-{train_on_last}', end='now', multi_index=True)
    df = df.reset_index(drop=True)
    df = df[sorted(df.columns)]
    df = dd.from_pandas(df, npartitions=shards)
    return df

# %%
def get_data_parquet(features_table):
    # Get parquet files
    mpath = [os.path.join(features_table, file) for file in os.listdir(features_table)]
    
    # Get latest filename
    latest = max(mpath, key=os.path.getmtime)
    
    # Load parquet to dask
    df = dd.read_parquet(latest)
    
    return df

# %%
def get_train_test_sets_from_data(df: pd.DataFrame, train_size: float=0.7, ):
    drop_columns = [col for col in df.columns if 'is_error' in col]
    X = df.drop(drop_columns, axis=1)
    y = df.loc[:, 'is_error']
    X_train, X_test, y_train, y_test = dcv.train_test_split(X, y, train_size=train_size, test_size=1-train_size)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Handler

# %%
def handler(context, event):
    
    mlctx = get_or_create_ctx('netops_training', event=event)
    
    context.logger.info(
        f'Run: {mlctx.name} uid={mlctx.uid}:{mlctx.iteration}')

    # Get properties from mlrun context
    save_to_tsdb = mlctx.get_param('from_tsdb', True)
    features_table = mlctx.get_param('features_table', 'netops_metrics')
    model_filepath = mlctx.get_param('model_filepath', '/v3io/bigdata/netops/models/')
    train_on_last = mlctx.get_param('TRAIN_ON_LAST', '7d')
    shards = mlctx.get_param('shards', 4)
    train_set_size = float(mlctx.get_param('TRAIN_SIZE', 0.7))
    
    # Verify model_filepath exists
    os.makedirs(model_filepath, exist_ok=True)

    # Handle source specific part
    if save_to_tsdb:
        # Create V3IO client
        client = v3f.Client(address='framesd:8081')
        
        # Create features table
        try:
            client.create('tsdb', features_table, attrs={'rate': '1/s'}, if_exists=1)
        except:
            context.logger.info(f'Frames bug IG-12910 handling {features_table}')

        # get training data reader from v3io source
        df = get_data_tsdb(client, features_table, train_on_last, shards)

    else:
        # Create features table
        filepath = os.path.join(features_table)
        os.makedirs(filepath, exist_ok=True)

        # get training data reader from parquet source
        df = get_data_parquet(features_table)

    # Split to Train / Test datasets
    X_train, X_test, y_train, y_test = get_train_test_sets_from_data(df, train_set_size)
    
    # Train
    model = xgb.XGBClassifier()
    model.fit(X_train, y_train)
    
    # Score
    score = model.score(X_test, y_test)
    mlctx.log_result('accuracy', score)
    
    # Save model
    full_model_path = f'{model_filepath}/netops_xgb.model'
    model.save_model(full_model_path)
    mlctx.log_artifact('model', full_model_path)

# %% [markdown]
# ## Test

# %%
# nuclio: ignore
event = nuclio.Event(body='')
output = handler(context, event)
output

# %% [markdown]
# ## Deployment

# %%
# nuclio: ignore
resp = run_start({}, handler=handler)
# Out:
# Python> 2019-08-09 09:00:03,747 [info] Run: netops_training uid=0b2b0c12fa65400ea7068c6a44972860:0
# <style>
# .dictlist {
#   background-color: #b3edff;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #ffe6cc;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #ffe6cc;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div title="0b2b0c12fa65400ea7068c6a44972860">...972860</div></td>
#       <td></td>
#       <td></td>
#       <td>completed</td>
#       <td></td>
#       <td><div class="dictlist">owner=iguazio</div><div class="dictlist">host=jupyter-70u91h6hx0-mmfj1-56b8bf8cf5-447q7</div><div class="dictlist">runtime=handler</div><div class="dictlist">repo=https://github.com/v3io/tutorials.git</div><div class="dictlist">commit=ead08b6662dbddced9974f5973c95396622e8407</div></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultcf8a872d-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultcf8a872d-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultcf8a872d" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultcf8a872d-body"></iframe>
#   </div>
# </div>

# %%
# nuclio: ignore

### Working ###
spec = nuclio.ConfigSpec(env=env_vars, 
                         cmd=build_commands,
                         config=configs,
                         mount=nuclio.Volume('User','~/'))

addr = nuclio.deploy_file('',name='training', project='netops_mlrun', verbose=False, spec=spec)
# Out:
# [nuclio.deploy] 2019-08-09 09:04:44,566 (info) Building processor image
# [nuclio.deploy] 2019-08-09 09:04:47,610 (info) Pushing image
# [nuclio.deploy] 2019-08-09 09:04:47,611 (info) Build complete
# [nuclio.deploy] 2019-08-09 09:04:53,690 (info) Function deploy complete
# [nuclio.deploy] 2019-08-09 09:04:53,697 done updating training, function address: 3.120.15.118:32242
